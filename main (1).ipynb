# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.pandas.set_option('display.max_column', None)

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(train.shape)
print(test.shape)
# Out:
# (891, 12)
# (418, 11)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.histplot(train['Age'], bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', hue='Sex', data=train)
plt.title('survived by gender')
# Out:
# Text(0.5, 1.0, 'survived by gender')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', hue='Pclass', data=train)
plt.title('survived by pesenger class')
# Out:
# Text(0.5, 1.0, 'survived by pesenger class')

# %%
sns.countplot(x='SibSp', data=train)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.histplot(train['Fare'], bins=10)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='Pclass', y='Age', data=train, palette='wintter')
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_11812\639200109.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Pclass', y='Age', data=train, palette='wintter')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\dataanv\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File ~\anaconda3\dataanv\Lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File ~\anaconda3\dataanv\Lib\site-packages\seaborn\_compat.py:62, in get_colormap(name)
#      61 try:
# ---> 62     return mpl.colormaps[name]
#      63 except AttributeError:
#
# File ~\anaconda3\dataanv\Lib\site-packages\matplotlib\cm.py:98, in ColormapRegistry.__getitem__(self, item)
#      97 except KeyError:
# ---> 98     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'wintter' is not a known colormap name"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 plt.figure(figsize=(12,7))
# ----> 2 sns.boxplot(x='Pclass', y='Age', data=train, palette='wintter')
#
# File ~\anaconda3\dataanv\Lib\site-packages\seaborn\categorical.py:1626, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1623 palette, hue_order = p._hue_backcompat(color, palette, hue_order)
#    1625 saturation = saturation if fill else 1
# -> 1626 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
#
# File ~\anaconda3\dataanv\Lib\site-packages\seaborn\_base.py:838, in VectorPlotter.map_hue(self, palette, order, norm, saturation)
#     837 def map_hue(self, palette=None, order=None, norm=None, saturation=1):
# --> 838     mapping = HueMapping(self, palette, order, norm, saturation)
#     839     self._hue_map = mapping
#
# File ~\anaconda3\dataanv\Lib\site-packages\seaborn\_base.py:150, in HueMapping.__init__(self, plotter, palette, order, norm, saturation)
#     147 elif map_type == "categorical":
#     149     cmap = norm = None
# --> 150     levels, lookup_table = self.categorical_mapping(
#     151         data, palette, order,
#     152     )
#     154 # --- Option 3: datetime mapping
#     155
#     156 else:
#     157     # TODO this needs actual implementation
#     158     cmap = norm = None
#
# File ~\anaconda3\dataanv\Lib\site-packages\seaborn\_base.py:248, in HueMapping.categorical_mapping(self, data, palette, order)
#     246         colors = self._check_list_length(levels, palette, "palette")
#     247     else:
# --> 248         colors = color_palette(palette, n_colors)
#     250     lookup_table = dict(zip(levels, colors))
#     252 return levels, lookup_table
#
# File ~\anaconda3\dataanv\Lib\site-packages\seaborn\palettes.py:237, in color_palette(palette, n_colors, desat, as_cmap)
#     235             palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236         except (ValueError, KeyError):  # Error class changed in mpl36
# --> 237             raise ValueError(f"{palette!r} is not a valid palette name")
#     239 if desat is not None:
#     240     palette = [desaturate(c, desat) for c in palette]
#
# ValueError: 'wintter' is not a valid palette name
